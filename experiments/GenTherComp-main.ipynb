# %% [markdown]
# # Generative Thermodynamic Computing Workflow
#
# 该 notebook 调用 `src/GenTherComp` 下拆分后的模块化实现。

# %%
from pathlib import Path
import sys
import numpy as np

# 确保 notebook 可导入 src 下包
repo_root = Path.cwd().resolve().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from src.GenTherComp import (
    demo_langevin_sampling,
    demo_swiss_roll,
    demo_gaussian_mixture,
    verify_universal_approximation,
)

# %%
print('=' * 60)
print('Generative Thermodynamic Computing - Notebook Workflow')
print('=' * 60)

np.random.seed(42)
print('随机种子设置完成: 42')
# Out:
# ============================================================
# Generative Thermodynamic Computing - Notebook Workflow
# ============================================================
# 随机种子设置完成: 42

# %%
# 演示 1: Langevin 动力学
demo_langevin_sampling()
# Out:
# ============================================================
# 演示：Langevin 动力学 - 双势阱采样
# ============================================================
# 采样数: 600000
# 均值:   0.0099 (理论值 ~ 0)
# 标准差: 0.9125
# 双峰位置: x ~ +-1
# 左峰均值: -0.8253, 右峰均值: 0.8277

# %%
# 演示 2: Swiss Roll
swiss_model, swiss_data, swiss_samples, swiss_losses = demo_swiss_roll()
# Out:
# ============================================================
# 演示：Swiss Roll 生成
# ============================================================
# 训练数据形状: (2000, 2)
# 数据范围: [-1.72, 2.04]
# Epoch   10/100 | Recon Error: 1.934442 | Free Energy: 0.9642
# Epoch   20/100 | Recon Error: 2.067157 | Free Energy: 0.9640
# Epoch   30/100 | Recon Error: 1.969514 | Free Energy: 0.9584
# Epoch   40/100 | Recon Error: 1.897516 | Free Energy: 0.9469
# Epoch   50/100 | Recon Error: 1.924322 | Free Energy: 0.9331
# Epoch   60/100 | Recon Error: 1.863225 | Free Energy: 0.9444
# Epoch   70/100 | Recon Error: 1.774188 | Free Energy: 0.9407
# Epoch   80/100 | Recon Error: 1.782921 | Free Energy: 0.9405
# Epoch   90/100 | Recon Error: 1.773447 | Free Energy: 0.9494
# Epoch  100/100 | Recon Error: 1.737378 | Free Energy: 0.9516
#
# 生成样本形状: (1000, 2)
# 生成范围: [-3.33, 2.98]
#
# --- 统计比较 ---
# 数据均值: [ 2.97317726e-16 -4.39648318e-17]
# 生成均值: [0.03771024 0.031096  ]
# 数据标准差: [1. 1.]
# 生成标准差: [1.05668041 1.01496463]

# %%
# 演示 3: 高斯混合模型
mix_model, mix_data, mix_samples, mix_losses = demo_gaussian_mixture()
# Out:
# ============================================================
# 演示：高斯混合模型生成
# ============================================================
# 训练数据形状: (2000, 2)
# Epoch   10/100 | Recon Error: 1.337084 | Free Energy: 0.6924
# Epoch   20/100 | Recon Error: 1.155185 | Free Energy: 0.8416
# Epoch   30/100 | Recon Error: 1.101986 | Free Energy: 0.9147
# Epoch   40/100 | Recon Error: 1.147759 | Free Energy: 0.9509
# Epoch   50/100 | Recon Error: 1.059887 | Free Energy: 0.9739
# Epoch   60/100 | Recon Error: 1.071635 | Free Energy: 0.9857
# Epoch   70/100 | Recon Error: 1.087630 | Free Energy: 0.9982
# Epoch   80/100 | Recon Error: 1.062998 | Free Energy: 1.0024
# Epoch   90/100 | Recon Error: 1.077338 | Free Energy: 1.0057
# Epoch  100/100 | Recon Error: 1.052522 | Free Energy: 1.0082
#
# 生成样本形状: (1000, 2)
#
# --- 统计比较 ---
# 数据均值: [ 0.02137389 -0.00650945]
# 生成均值: [0.02348339 0.00041397]

# %%
# 演示 4: 通用近似定理验证
ua_results = verify_universal_approximation()
# Out:
# ============================================================
# 验证：通用近似定理
# ============================================================
#
# n_hidden = 10
#   自由能: 0.9056, 最终重构误差: 1.220480
#
# n_hidden = 25
#   自由能: 0.9119, 最终重构误差: 1.211763
#
# n_hidden = 50
#   自由能: 0.9124, 最终重构误差: 1.224246
#
# n_hidden = 100
#   自由能: 0.9087, 最终重构误差: 1.210401
#
# n_hidden = 200
#   自由能: 0.9093, 最终重构误差: 1.241074
#
# --- 结果汇总 ---
#   n_hidden |  Free Energy |  Recon Error
# ----------------------------------------
#         10 |       0.9056 |     1.220480
#         25 |       0.9119 |     1.211763
#         50 |       0.9124 |     1.224246
#        100 |       0.9087 |     1.210401
#        200 |       0.9093 |     1.241074
#
# 理论预期：随着 n_hidden 增加，自由能和重构误差应趋于下降。
